# %% [markdown]
# # RQ6: Which impact do sliding window size and overlap size have on model performance?
#
# num_epoch = 10
# batch_size = 4 (default)
# Overlap sizes:
# - 25% (1/4) (done) = 75% overlap
#     - train: 5:53h per epoch
#     - batch_size = 3
#     - train file 3G
#     - 321,724 lines
# - 50% (1/2) (done) = 50% overlap
#     - train: 3:43h per epoch
#     - batch_size = 4
#     - train file 1.9G
#     - 220,162 lines
# - 70% (1/1.4) (evaluating) = 30% overlap
#     - train: 3:03h per epoch
#     - train file 1.6G
#     - 189,882 lines
# - 90% (1/1.1) (evaluating) = 10% overlap
#     - train: 2:34h
#     - train file 1.4G
#     - 174,870 lines
#
# ## Model training times
#
# ## Model evaluation
#
# ## Comparison with RQ1

# %%
import pickle

value_scores_75 = {
    "attr_ids": {
        "t_score": [0.87, 0.95, 0.96, 0.98, 0.98, 0.98, 0.99, 0.99, 0.99, 0.99],
        "v_score": [0.08, 0.14, 0.19, 0.34, 0.4, 0.43, 0.45, 0.47, 0.48, 0.5],
        "label": "Attribute Access"
    },
    "num_ids": {
        "t_score": [0.47, 0.5, 0.6, 0.58, 0.67, 0.7, 0.73, 0.74, 0.75, 0.76],
        "v_score": [0.45, 0.47, 0.52, 0.54, 0.58, 0.6, 0.61, 0.62, 0.62, 0.63],
        "label": "Numeric Constant"
    },
    "name_ids": {
        "t_score": [0.86, 0.87, 0.89, 0.91, 0.92, 0.92, 0.92, 0.93, 0.93, 0.93],
        "v_score": [0.22, 0.32, 0.38, 0.48, 0.53, 0.55, 0.56, 0.58, 0.59, 0.6],
        "label": "Variable Name/Module Name"
    },
    "param_ids": {
        "t_score": [0.86, 0.89, 0.9, 0.92, 0.93, 0.92, 0.93, 0.93, 0.94, 0.94],
        "v_score": [0.49, 0.51, 0.54, 0.56, 0.56, 0.6, 0.6, 0.61, 0.61, 0.62],
        "label": "Function Parameter Name"
    },
    "string_ids": {
        "t_score": [0.55, 0.69, 0.71, 0.72, 0.76, 0.78, 0.85, 0.86, 0.88, 0.89],
        "v_score": [0.03, 0.04, 0.05, 0.08, 0.11, 0.13, 0.14, 0.15, 0.16, 0.17],
        "label": "Strings"
    }
}
type_scores_75 = {
    "call_ids": {
        "score": [0.25, 0.29, 0.32, 0.39, 0.42, 0.44, 0.45, 0.47, 0.48, 0.48],
        "label": "Function Call"
    },
    "assign_ids": {
        "score": [0.28, 0.39, 0.43, 0.47, 0.51, 0.52, 0.54, 0.55, 0.56, 0.57],
        "label": "Assignment"
    },
    "return_ids": {
        "score": [0.32, 0.44, 0.49, 0.54, 0.57, 0.58, 0.6, 0.62, 0.62, 0.63],
        "label": "Return"
    },
    "list_ids": {
        "score": [0.05, 0.09, 0.13, 0.19, 0.25, 0.27, 0.28, 0.3, 0.31, 0.32],
        "label": "List"
    },
    "dict_ids": {
        "score": [0.05, 0.09, 0.13, 0.16, 0.19, 0.2, 0.19, 0.2, 0.2, 0.2],
        "label": "Dictionary"
    },
    "raise_ids": {
        "score": [0.37, 0.67, 0.73, 0.76, 0.77, 0.78, 0.8, 0.8, 0.81, 0.82],
        "label": "Raise"
    }
}
value_scores_50 = {
    "attr_ids": {
        "t_score": [0.87, 0.96, 0.98, 0.95, 0.96, 0.97, 0.98, 0.99, 0.99, 0.99],
        "v_score": [0.08, 0.11, 0.16, 0.24, 0.34, 0.38, 0.42, 0.44, 0.46, 0.47],
        "label": "Attribute Access"
    },
    "num_ids": {
        "t_score": [0.36, 0.44, 0.48, 0.55, 0.57, 0.62, 0.67, 0.69, 0.71, 0.72],
        "v_score": [0.46, 0.47, 0.5, 0.52, 0.54, 0.55, 0.58, 0.59, 0.61, 0.61],
        "label": "Numeric Constant"
    },
    "name_ids": {
        "t_score": [0.86, 0.87, 0.89, 0.89, 0.9, 0.91, 0.92, 0.92, 0.92, 0.93],
        "v_score": [0.21, 0.28, 0.35, 0.4, 0.48, 0.51, 0.55, 0.57, 0.58, 0.59],
        "label": "Variable Name/Module Name"
    },
    "param_ids": {
        "t_score": [0.8, 0.91, 0.9, 0.9, 0.9, 0.93, 0.92, 0.92, 0.93, 0.92],
        "v_score": [0.48, 0.50, 0.52, 0.54, 0.55, 0.6, 0.57, 0.58, 0.59, 0.59],
        "label": "Function Parameter Name"
    },
    "string_ids": {
        "t_score": [0.64, 0.71, 0.75, 0.73, 0.78, 0.83, 0.82, 0.84, 0.84, 0.85],
        "v_score": [0.02, 0.03, 0.05, 0.06, 0.09, 0.10, 0.12, 0.13, 0.14, 0.15],
        "label": "Strings"
    }
}
type_scores_50 = {
    "call_ids": {
        "score": [0.22, 0.28, 0.3, 0.34, 0.38, 0.39, 0.42, 0.44, 0.45, 0.46],
        "label": "Function Call"
    },
    "assign_ids": {
        "score": [0.27, 0.36, 0.4, 0.42, 0.46, 0.49, 0.52, 0.53, 0.55, 0.55],
        "label": "Assignment"
    },
    "return_ids": {
        "score": [0.3, 0.41, 0.45, 0.48, 0.53, 0.56, 0.58, 0.6, 0.61, 0.62],
        "label": "Return"
    },
    "list_ids": {
        "score": [0.04, 0.08, 0.1, 0.13, 0.19, 0.21, 0.24, 0.27, 0.28, 0.3],
        "label": "List"
    },
    "dict_ids": {
        "score": [0.05, 0.07, 0.11, 0.12, 0.15, 0.16, 0.19, 0.19, 0.19, 0.21],
        "label": "Dictionary"
    },
    "raise_ids": {
        "score": [0.33, 0.62, 0.66, 0.68, 0.71, 0.75, 0.76, 0.78, 0.79, 0.8],
        "label": "Raise"
    }
}

value_scores_30 = {
    "attr_ids": {
        "t_score": [0.84, 0.94, 0.96, 0.95, 0.97, 0.96, 0.97, 0.98, 0.98, 0.98],
        "v_score": [0.07, 0.11, 0.16, 0.23, 0.32, 0.36, 0.4, 0.42, 0.43, 0.44],
        "label": "Attribute Access"
    },
    "num_ids": {
        "t_score": [0.31, 0.43, 0.43, 0.46, 0.53, 0.55, 0.58, 0.63, 0.66, 0.69],
        "v_score": [0.46, 0.47, 0.48, 0.5, 0.52, 0.54, 0.56, 0.58, 0.58, 0.59],
        "label": "Numeric Constant"
    },
    "name_ids": {
        "t_score": [0.84, 0.87, 0.9, 0.88, 0.88, 0.89, 0.9, 0.9, 0.91, 0.91],
        "v_score": [0.2, 0.27, 0.33, 0.39, 0.45, 0.48, 0.52, 0.54, 0.56, 0.56],
        "label": "Variable Name/Module Name"
    },
    "param_ids": {
        "t_score": [0.83, 0.87, 0.87, 0.87, 0.86, 0.86, 0.87, 0.89, 0.9, 0.91],
        "v_score": [0.48, 0.5, 0.51, 0.53, 0.54, 0.56, 0.56, 0.57, 0.57, 0.58],
        "label": "Function Parameter Name"
    },
    "string_ids": {
        "t_score": [0.6, 0.71, 0.7, 0.72, 0.75, 0.77, 0.79, 0.82, 0.83, 0.85],
        "v_score": [0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.11, 0.12, 0.13, 0.14],
        "label": "Strings"
    }
}
type_scores_30 = {
    "call_ids": {
        "score": [0.24, 0.26, 0.29, 0.32, 0.35, 0.39, 0.41, 0.42, 0.43, 0.44],
        "label": "Function Call"
    },
    "assign_ids": {
        "score": [0.29, 0.34, 0.38, 0.41, 0.44, 0.47, 0.49, 0.52, 0.52, 0.53],
        "label": "Assignment"
    },
    "return_ids": {
        "score": [0.32, 0.38, 0.42, 0.46, 0.48, 0.51, 0.55, 0.57, 0.58, 0.59],
        "label": "Return"
    },
    "list_ids": {
        "score": [0.04, 0.07, 0.1, 0.12, 0.17, 0.2, 0.23, 0.25, 0.27, 0.27],
        "label": "List"
    },
    "dict_ids": {
        "score": [0.05, 0.07, 0.09, 0.12, 0.13, 0.15, 0.16, 0.18, 0.18, 0.18],
        "label": "Dictionary"
    },
    "raise_ids": {
        "score": [0.43, 0.53, 0.61, 0.64, 0.66, 0.69, 0.73, 0.76, 0.76, 0.78],
        "label": "Raise"
    }
}
value_scores_10 = {
    "attr_ids": {
        "t_score": [0.8, 0.93, 0.94, 0.95, 0.96, 0.97, 0.97, 0.95, 0.96, 0.94],
        "v_score": [0.07, 0.1, 0.13, 0.18, 0.24, 0.32, 0.35, 0.37, 0.39, 0.4],
        "label": "Attribute Access"
    },
    "num_ids": {
        "t_score": [0.33, 0.35, 0.41, 0.44, 0.49, 0.5, 0.56, 0.59, 0.62, 0.61],
        "v_score": [0.44, 0.47, 0.48, 0.5, 0.51, 0.53, 0.54, 0.56, 0.57, 0.57],
        "label": "Numeric Constant"
    },
    "name_ids": {
        "t_score": [0.88, 0.86, 0.85, 0.86, 0.88, 0.88, 0.87, 0.87, 0.88, 0.87],
        "v_score": [0.2, 0.25, 0.29, 0.34, 0.39, 0.44, 0.47, 0.48, 0.51, 0.51],
        "label": "Variable Name/Module Name"
    },
    "param_ids": {
        "t_score": [0.78, 0.88, 0.88, 0.9, 0.9, 0.89, 0.87, 0.86, 0.85, 0.84],
        "v_score": [0.48, 0.5, 0.5, 0.51, 0.52, 0.53, 0.53, 0.53, 0.53, 0.53],
        "label": "Function Parameter Name"
    },
    "string_ids": {
        "t_score": [0.62, 0.67, 0.69, 0.73, 0.76, 0.77, 0.8, 0.81, 0.82, 0.82],
        "v_score": [0.02, 0.03, 0.04, 0.04, 0.06, 0.08, 0.1, 0.1, 0.11, 0.11],
        "label": "Strings"
    }
}
type_scores_10 = {
    "call_ids": {
        "score": [0.22, 0.25, 0.28, 0.31, 0.34, 0.36, 0.38, 0.4, 0.41, 0.42],
        "label": "Function Call"
    },
    "assign_ids": {
        "score": [0.27, 0.32, 0.35, 0.38, 0.42, 0.44, 0.46, 0.47, 0.49, 0.49],
        "label": "Assignment"
    },
    "return_ids": {
        "score": [0.31, 0.36, 0.4, 0.43, 0.47, 0.5, 0.52, 0.53, 0.54, 0.54],
        "label": "Return"
    },
    "list_ids": {
        "score": [0.04, 0.06, 0.09, 0.11, 0.14, 0.17, 0.2, 0.21, 0.23, 0.23],
        "label": "List"
    },
    "dict_ids": {
        "score": [0.05, 0.06, 0.08, 0.1, 0.13, 0.14, 0.15, 0.16, 0.17, 0.16],
        "label": "Dictionary"
    },
    "raise_ids": {
        "score": [0.38, 0.5, 0.56, 0.61, 0.68, 0.7, 0.71, 0.72, 0.73, 0.73],
        "label": "Raise"
    }
}

with open("rq6/scores.pkl", "wb") as fout:
    pickle.dump({"value_scores": 
                     [value_scores_75, value_scores_50, value

# %%
import pickle

value_scores_75 = {
    "attr_ids": {
        "t_score": [0.87, 0.95, 0.96, 0.98, 0.98, 0.98, 0.99, 0.99, 0.99, 0.99],
        "v_score": [0.08, 0.14, 0.19, 0.34, 0.4, 0.43, 0.45, 0.47, 0.48, 0.5],
        "label": "Attribute Access"
    },
    "num_ids": {
        "t_score": [0.47, 0.5, 0.6, 0.58, 0.67, 0.7, 0.73, 0.74, 0.75, 0.76],
        "v_score": [0.45, 0.47, 0.52, 0.54, 0.58, 0.6, 0.61, 0.62, 0.62, 0.63],
        "label": "Numeric Constant"
    },
    "name_ids": {
        "t_score": [0.86, 0.87, 0.89, 0.91, 0.92, 0.92, 0.92, 0.93, 0.93, 0.93],
        "v_score": [0.22, 0.32, 0.38, 0.48, 0.53, 0.55, 0.56, 0.58, 0.59, 0.6],
        "label": "Variable Name/Module Name"
    },
    "param_ids": {
        "t_score": [0.86, 0.89, 0.9, 0.92, 0.93, 0.92, 0.93, 0.93, 0.94, 0.94],
        "v_score": [0.49, 0.51, 0.54, 0.56, 0.56, 0.6, 0.6, 0.61, 0.61, 0.62],
        "label": "Function Parameter Name"
    },
    "string_ids": {
        "t_score": [0.55, 0.69, 0.71, 0.72, 0.76, 0.78, 0.85, 0.86, 0.88, 0.89],
        "v_score": [0.03, 0.04, 0.05, 0.08, 0.11, 0.13, 0.14, 0.15, 0.16, 0.17],
        "label": "Strings"
    }
}
type_scores_75 = {
    "call_ids": {
        "score": [0.25, 0.29, 0.32, 0.39, 0.42, 0.44, 0.45, 0.47, 0.48, 0.48],
        "label": "Function Call"
    },
    "assign_ids": {
        "score": [0.28, 0.39, 0.43, 0.47, 0.51, 0.52, 0.54, 0.55, 0.56, 0.57],
        "label": "Assignment"
    },
    "return_ids": {
        "score": [0.32, 0.44, 0.49, 0.54, 0.57, 0.58, 0.6, 0.62, 0.62, 0.63],
        "label": "Return"
    },
    "list_ids": {
        "score": [0.05, 0.09, 0.13, 0.19, 0.25, 0.27, 0.28, 0.3, 0.31, 0.32],
        "label": "List"
    },
    "dict_ids": {
        "score": [0.05, 0.09, 0.13, 0.16, 0.19, 0.2, 0.19, 0.2, 0.2, 0.2],
        "label": "Dictionary"
    },
    "raise_ids": {
        "score": [0.37, 0.67, 0.73, 0.76, 0.77, 0.78, 0.8, 0.8, 0.81, 0.82],
        "label": "Raise"
    }
}
value_scores_50 = {
    "attr_ids": {
        "t_score": [0.87, 0.96, 0.98, 0.95, 0.96, 0.97, 0.98, 0.99, 0.99, 0.99],
        "v_score": [0.08, 0.11, 0.16, 0.24, 0.34, 0.38, 0.42, 0.44, 0.46, 0.47],
        "label": "Attribute Access"
    },
    "num_ids": {
        "t_score": [0.36, 0.44, 0.48, 0.55, 0.57, 0.62, 0.67, 0.69, 0.71, 0.72],
        "v_score": [0.46, 0.47, 0.5, 0.52, 0.54, 0.55, 0.58, 0.59, 0.61, 0.61],
        "label": "Numeric Constant"
    },
    "name_ids": {
        "t_score": [0.86, 0.87, 0.89, 0.89, 0.9, 0.91, 0.92, 0.92, 0.92, 0.93],
        "v_score": [0.21, 0.28, 0.35, 0.4, 0.48, 0.51, 0.55, 0.57, 0.58, 0.59],
        "label": "Variable Name/Module Name"
    },
    "param_ids": {
        "t_score": [0.8, 0.91, 0.9, 0.9, 0.9, 0.93, 0.92, 0.92, 0.93, 0.92],
        "v_score": [0.48, 0.50, 0.52, 0.54, 0.55, 0.6, 0.57, 0.58, 0.59, 0.59],
        "label": "Function Parameter Name"
    },
    "string_ids": {
        "t_score": [0.64, 0.71, 0.75, 0.73, 0.78, 0.83, 0.82, 0.84, 0.84, 0.85],
        "v_score": [0.02, 0.03, 0.05, 0.06, 0.09, 0.10, 0.12, 0.13, 0.14, 0.15],
        "label": "Strings"
    }
}
type_scores_50 = {
    "call_ids": {
        "score": [0.22, 0.28, 0.3, 0.34, 0.38, 0.39, 0.42, 0.44, 0.45, 0.46],
        "label": "Function Call"
    },
    "assign_ids": {
        "score": [0.27, 0.36, 0.4, 0.42, 0.46, 0.49, 0.52, 0.53, 0.55, 0.55],
        "label": "Assignment"
    },
    "return_ids": {
        "score": [0.3, 0.41, 0.45, 0.48, 0.53, 0.56, 0.58, 0.6, 0.61, 0.62],
        "label": "Return"
    },
    "list_ids": {
        "score": [0.04, 0.08, 0.1, 0.13, 0.19, 0.21, 0.24, 0.27, 0.28, 0.3],
        "label": "List"
    },
    "dict_ids": {
        "score": [0.05, 0.07, 0.11, 0.12, 0.15, 0.16, 0.19, 0.19, 0.19, 0.21],
        "label": "Dictionary"
    },
    "raise_ids": {
        "score": [0.33, 0.62, 0.66, 0.68, 0.71, 0.75, 0.76, 0.78, 0.79, 0.8],
        "label": "Raise"
    }
}

value_scores_30 = {
    "attr_ids": {
        "t_score": [0.84, 0.94, 0.96, 0.95, 0.97, 0.96, 0.97, 0.98, 0.98, 0.98],
        "v_score": [0.07, 0.11, 0.16, 0.23, 0.32, 0.36, 0.4, 0.42, 0.43, 0.44],
        "label": "Attribute Access"
    },
    "num_ids": {
        "t_score": [0.31, 0.43, 0.43, 0.46, 0.53, 0.55, 0.58, 0.63, 0.66, 0.69],
        "v_score": [0.46, 0.47, 0.48, 0.5, 0.52, 0.54, 0.56, 0.58, 0.58, 0.59],
        "label": "Numeric Constant"
    },
    "name_ids": {
        "t_score": [0.84, 0.87, 0.9, 0.88, 0.88, 0.89, 0.9, 0.9, 0.91, 0.91],
        "v_score": [0.2, 0.27, 0.33, 0.39, 0.45, 0.48, 0.52, 0.54, 0.56, 0.56],
        "label": "Variable Name/Module Name"
    },
    "param_ids": {
        "t_score": [0.83, 0.87, 0.87, 0.87, 0.86, 0.86, 0.87, 0.89, 0.9, 0.91],
        "v_score": [0.48, 0.5, 0.51, 0.53, 0.54, 0.56, 0.56, 0.57, 0.57, 0.58],
        "label": "Function Parameter Name"
    },
    "string_ids": {
        "t_score": [0.6, 0.71, 0.7, 0.72, 0.75, 0.77, 0.79, 0.82, 0.83, 0.85],
        "v_score": [0.02, 0.03, 0.04, 0.06, 0.08, 0.1, 0.11, 0.12, 0.13, 0.14],
        "label": "Strings"
    }
}
type_scores_30 = {
    "call_ids": {
        "score": [0.24, 0.26, 0.29, 0.32, 0.35, 0.39, 0.41, 0.42, 0.43, 0.44],
        "label": "Function Call"
    },
    "assign_ids": {
        "score": [0.29, 0.34, 0.38, 0.41, 0.44, 0.47, 0.49, 0.52, 0.52, 0.53],
        "label": "Assignment"
    },
    "return_ids": {
        "score": [0.32, 0.38, 0.42, 0.46, 0.48, 0.51, 0.55, 0.57, 0.58, 0.59],
        "label": "Return"
    },
    "list_ids": {
        "score": [0.04, 0.07, 0.1, 0.12, 0.17, 0.2, 0.23, 0.25, 0.27, 0.27],
        "label": "List"
    },
    "dict_ids": {
        "score": [0.05, 0.07, 0.09, 0.12, 0.13, 0.15, 0.16, 0.18, 0.18, 0.18],
        "label": "Dictionary"
    },
    "raise_ids": {
        "score": [0.43, 0.53, 0.61, 0.64, 0.66, 0.69, 0.73, 0.76, 0.76, 0.78],
        "label": "Raise"
    }
}
value_scores_10 = {
    "attr_ids": {
        "t_score": [0.8, 0.93, 0.94, 0.95, 0.96, 0.97, 0.97, 0.95, 0.96, 0.94],
        "v_score": [0.07, 0.1, 0.13, 0.18, 0.24, 0.32, 0.35, 0.37, 0.39, 0.4],
        "label": "Attribute Access"
    },
    "num_ids": {
        "t_score": [0.33, 0.35, 0.41, 0.44, 0.49, 0.5, 0.56, 0.59, 0.62, 0.61],
        "v_score": [0.44, 0.47, 0.48, 0.5, 0.51, 0.53, 0.54, 0.56, 0.57, 0.57],
        "label": "Numeric Constant"
    },
    "name_ids": {
        "t_score": [0.88, 0.86, 0.85, 0.86, 0.88, 0.88, 0.87, 0.87, 0.88, 0.87],
        "v_score": [0.2, 0.25, 0.29, 0.34, 0.39, 0.44, 0.47, 0.48, 0.51, 0.51],
        "label": "Variable Name/Module Name"
    },
    "param_ids": {
        "t_score": [0.78, 0.88, 0.88, 0.9, 0.9, 0.89, 0.87, 0.86, 0.85, 0.84],
        "v_score": [0.48, 0.5, 0.5, 0.51, 0.52, 0.53, 0.53, 0.53, 0.53, 0.53],
        "label": "Function Parameter Name"
    },
    "string_ids": {
        "t_score": [0.62, 0.67, 0.69, 0.73, 0.76, 0.77, 0.8, 0.81, 0.82, 0.82],
        "v_score": [0.02, 0.03, 0.04, 0.04, 0.06, 0.08, 0.1, 0.1, 0.11, 0.11],
        "label": "Strings"
    }
}
type_scores_10 = {
    "call_ids": {
        "score": [0.22, 0.25, 0.28, 0.31, 0.34, 0.36, 0.38, 0.4, 0.41, 0.42],
        "label": "Function Call"
    },
    "assign_ids": {
        "score": [0.27, 0.32, 0.35, 0.38, 0.42, 0.44, 0.46, 0.47, 0.49, 0.49],
        "label": "Assignment"
    },
    "return_ids": {
        "score": [0.31, 0.36, 0.4, 0.43, 0.47, 0.5, 0.52, 0.53, 0.54, 0.54],
        "label": "Return"
    },
    "list_ids": {
        "score": [0.04, 0.06, 0.09, 0.11, 0.14, 0.17, 0.2, 0.21, 0.23, 0.23],
        "label": "List"
    },
    "dict_ids": {
        "score": [0.05, 0.06, 0.08, 0.1, 0.13, 0.14, 0.15, 0.16, 0.17, 0.16],
        "label": "Dictionary"
    },
    "raise_ids": {
        "score": [0.38, 0.5, 0.56, 0.61, 0.68, 0.7, 0.71, 0.72, 0.73, 0.73],
        "label": "Raise"
    }
}

with open("rq6/scores.pkl", "wb") as fout:
    pickle.dump({"value_scores": 
                     [value_scores_75, value_scores_50, value_scores_30, value_scores_10], 
                 "type_scores": 
                     [type_scores_75, type_scores_50, type_scores_30, type_scores_10]
                }, fout)

# %% [markdown]
# ## Training duration vs file size

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib import rcParams
rcParams.update({'font.size': 14})
rcParams["figure.figsize"] = (14,6)

file_sizes = [174870, 189882, 220162, 321724]
train_times = [1540, 1830, 2230, 3530]
x = [10, 30, 50, 75]

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, train_times, "blue")
ax2.plot(x, file_sizes, "green")

ax1.title.set_text('Training duration vs. file size')
ax1.set_xlabel("Overlap in percent")
ax1.set_ylabel("Training time in minutes", color="blue")
ax2.set_ylabel("Training file line count", color="green")
ax1.set_xticks(x)

# %% [markdown]
# ## Training duration vs performance

# %%
scores = pickle.load(open("rq6/scores.pkl", "rb"))

means = {
    "overlap_75": [],
    "overlap_50": [],
    "overlap_30": [],
    "overlap_10": []
}

for j,o in enumerate(means):
    for i in range(10):
        means[o].append(
            (scores["value_scores"][j]["attr_ids"]["t_score"][i] + 
            scores["value_scores"][j]["attr_ids"]["v_score"][i] + 
            scores["value_scores"][j]["num_ids"]["t_score"][i] + 
            scores["value_scores"][j]["num_ids"]["v_score"][i] + 
            scores["value_scores"][j]["name_ids"]["t_score"][i] + 
            scores["value_scores"][j]["name_ids"]["v_score"][i] + 
            scores["value_scores"][j]["param_ids"]["t_score"][i] + 
            scores["value_scores"][j]["param_ids"]["v_score"][i] + 
            scores["value_scores"][j]["string_ids"]["t_score"][i] + 
            scores["value_scores"][j]["string_ids"]["v_score"][i] + 
            scores["type_scores"][j]["call_ids"]["score"][i] + 
            scores["type_scores"][j]["assign_ids"]["score"][i] + 
            scores["type_scores"][j]["return_ids"]["score"][i] + 
            scores["type_scores"][j]["list_ids"]["score"][i] + 
            scores["type_scores"][j]["dict_ids"]["score"][i] + 
            scores["type_scores"][j]["raise_ids"]["score"][i]
            ) / 16
        )

final_model_scores = list(reversed([s[-1] for _, s in means.items()]))

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.plot(x, train_times, "blue")
ax2.plot(x, final_model_scores, "green")

ax1.title.set_text('Training duration vs. model performance')
ax1.set_xlabel("Overlap in percent")
ax1.set_ylabel("Training time in minutes", color="blue")
ax2.set_ylabel("Average model performance", color="green")
ax1.set_xticks(x)
